# %% [markdown]
# WEEK 1: Data Collection, Environment Setup & Data Cleaning

# %%
import pandas as pd
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\INDIA\OneDrive\Desktop\Infotact_Omnichannel_Retail_Analytics\Dataset\archive (1)

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'dim_brand.parquet', 'dim_campaign.parquet', 'dim_category.parquet', 'dim_customer.parquet', 'dim_date.parquet', 'dim_location.parquet', 'dim_product.parquet', 'dim_promotion.parquet', 'dim_store.parquet', 'dim_subcategory.parquet', 'fact_clickstream.parquet', 'fact_sale.parquet', 'fact_transaction.parquet', 'inventory.parquet', 'Untitled.ipynb']

# %%
sales = pd.read_parquet("fact_sale.parquet")
sales.head()
# Out:
#     sale_id  transaction_id  session_id transaction_timestamp  \
# 0  12000363         8000125   9000924.0   2023-07-09 14:24:59
# 1  12000364         8000125   9000924.0   2023-07-09 14:24:59
# 2  12000365         8000126   9000930.0   2023-08-05 00:34:50
# 3  12000366         8000126   9000930.0   2023-08-05 00:34:50
# 4  12000367         8000126   9000930.0   2023-08-05 00:34:50
#
#    transaction_date_id  product_id  quantity unit_cost unit_price line_cost  \
# 0             20230709         335         1     20.00      24.25     20.00
# 1             20230709         440         1     98.00     131.09     98.00
# 2             20230805         165         1     20.00      24.17     20.00
# 3             20230805         135         1    230.00     277.14    230.00
# 4             20230805         399         1    140.00     167.43    140.00
#
#   line_total aov_category
# 0      24.25          Low
# 1     131.09          Low
# 2      24.17          Low
# ...

# %%
sales.shape
# Out:
# (1799836, 12)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1799836 entries, 0 to 1799835
# Data columns (total 12 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   sale_id                int32
#  1   transaction_id         int32
#  2   session_id             float64
#  3   transaction_timestamp  datetime64[us]
#  4   transaction_date_id    int32
#  5   product_id             int32
#  6   quantity               int32
#  7   unit_cost              object
#  8   unit_price             object
#  9   line_cost              object
#  10  line_total             object
#  11  aov_category           object
# dtypes: datetime64[us](1), float64(1), int32(5), object(5)
# memory usage: 130.5+ MB

# %%
sales.columns.tolist()
# Out:
# ['sale_id',
#  'transaction_id',
#  'session_id',
#  'transaction_timestamp',
#  'transaction_date_id',
#  'product_id',
#  'quantity',
#  'unit_cost',
#  'unit_price',
#  'line_cost',
#  'line_total',
#  'aov_category']

# %%
sales.isnull().sum()
# Out:
# sale_id                       0
# transaction_id                0
# session_id               679257
# transaction_timestamp         0
# transaction_date_id           0
# product_id                    0
# quantity                      0
# unit_cost                     0
# unit_price                    0
# line_cost                     0
# line_total                    0
# aov_category                  0
# dtype: int64

# %%
sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
sales.describe()
# Out:
#             sale_id  transaction_id    session_id       transaction_timestamp  \
# count  1.799836e+06    1.799836e+06  1.120579e+06                     1799836
# mean   1.290028e+07    8.450064e+06  1.728324e+07  2024-11-19 03:38:07.403819
# min    1.200036e+07    8.000125e+06  9.000864e+06         2023-01-01 00:26:35
# 25%    1.245032e+07    8.225082e+06  1.404357e+07  2024-04-16 09:10:34.750000
# 50%    1.290028e+07    8.450138e+06  1.782423e+07         2025-01-07 16:51:37
# 75%    1.335024e+07    8.674933e+06  2.065788e+07         2025-07-30 08:24:28
# max    1.380020e+07    8.900124e+06  2.350086e+07         2025-12-31 23:44:00
# std    5.195680e+05    2.597789e+05  3.993262e+06                         NaN
#
#        transaction_date_id    product_id   quantity
# count         1.799836e+06  1.799836e+06  1799836.0
# mean          2.024407e+07  2.327813e+02        1.0
# min           2.023010e+07  1.000000e+00        1.0
# 25%           2.024042e+07  1.160000e+02        1.0
# ...

# %% [markdown]
# # Initial Assessment
#
# Rows: 1,799,836
#
# Columns: 12
#
# Observations:
# - To be filled after NULL analysis
# - To be filled after duplicate analysis
# - To be filled after datatype analysis

# %%
customer = pd.read_parquet("dim_customer.parquet")

customer.shape
# Out:
# (150000, 16)

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   customer_id              150000 non-null  int32
#  1   email_address            150000 non-null  object
#  2   first_name               150000 non-null  object
#  3   last_name                150000 non-null  object
#  4   gender                   150000 non-null  object
#  5   customer_persona         150000 non-null  object
#  6   birth_date               150000 non-null  object
#  7   birth_year               150000 non-null  int32
#  8   location_id              150000 non-null  int32
#  9   signup_date              150000 non-null  datetime64[us]
#  10  signup_date_id           150000 non-null  int32
#  11  signup_channel           150000 non-null  object
#  12  loyalty_status           150000 non-null  object
# ...

# %%
customer.head()
# Out:
#    customer_id                  email_address first_name last_name  gender  \
# 0            1     diana.haynes.1@example.com      diana    haynes  Female
# 1            2          joyce.simon.2@bac.com      joyce     simon  Female
# 2            3    monique.colon.3@example.com    monique     colon  Female
# 3            4  elizabeth.heath.4@example.com  elizabeth     heath  Female
# 4            5       pamela.coleman.5@xyz.com     pamela   coleman  Female
#
#    customer_persona  birth_date  birth_year  location_id signup_date  \
# 0   Tech Enthusiast  2000-12-31        2000            4  2019-12-23
# 1   Tech Enthusiast  2000-01-01        2000            1  2021-09-14
# 2  Everyday Shopper  1976-12-31        1976            3  2008-07-27
# 3  Everyday Shopper  1987-01-01        1987            3  2009-10-14
# 4   Tech Enthusiast  1995-01-01        1995            2  2024-02-26
#
#    signup_date_id signup_channel loyalty_status estimated_annual_income  \
# ...

# %%
product = pd.read_parquet("dim_product.parquet")

product.shape
# Out:
# (470, 9)

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470 entries, 0 to 469
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   product_id       470 non-null    int32
#  1   product_name     470 non-null    object
#  2   category_id      470 non-null    int32
#  3   subcategory_id   470 non-null    int32
#  4   brand_id         470 non-null    int32
#  5   unit_cost        470 non-null    object
#  6   unit_price       470 non-null    object
#  7   warranty_years   470 non-null    int32
#  8   product_segment  470 non-null    object
# dtypes: int32(5), object(4)
# memory usage: 24.0+ KB

# %%
product.head()
# Out:
#    product_id                                product_name  category_id  \
# 0           1  Philips 55PUT7630/98 55'' UHD Smart Led TV            1
# 1           2          Samsung UE55U8000FUXMU 55'' Led TV            1
# 2           3          Samsung TU32H5005FKXXC 32'' Led TV            1
# 3           4          Samsung UE43U8000FUXMU 43'' Led TV            1
# 4           5            Philips 40PFT6509/98 40'' Led TV            1
#
#    subcategory_id  brand_id unit_cost unit_price  warranty_years  \
# 0               1         1    280.00     327.68               2
# 1               1         2    310.00     372.46               2
# 2               1         2    160.00     179.74               2
# 3               1         2    230.00     271.20               2
# 4               1         1    140.00     169.46               2
#
#   product_segment
# 0        Mid Tier
# 1        Mid Tier
# 2     Entry Level
# 3     Entry Level
# 4     Entry Level

# %%
store = pd.read_parquet("dim_store.parquet")

store.shape
# Out:
# (50, 8)

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   store_id            50 non-null     int32
#  1   store_name          50 non-null     object
#  2   location_id         50 non-null     int32
#  3   store_type          50 non-null     object
#  4   store_size          50 non-null     int32
#  5   opening_date        50 non-null     datetime64[us]
#  6   opening_date_id     50 non-null     int32
#  7   foot_traffic_index  50 non-null     int32
# dtypes: datetime64[us](1), int32(5), object(2)
# memory usage: 2.3+ KB

# %%
store.head()
# Out:
#    store_id          store_name  location_id  store_type  store_size  \
# 0         1  ELEC-MART Store #1            9      Outlet         774
# 1         2  ELEC-MART Store #2            6   Warehouse        3863
# 2         3  ELEC-MART Store #3            8  Standalone        1142
# 3         4  ELEC-MART Store #4            7  Standalone         963
# 4         5  ELEC-MART Store #5            4        Mall         395
#
#          opening_date  opening_date_id  foot_traffic_index
# 0 2001-05-30 10:00:00         20010530                  53
# 1 2001-12-18 10:00:00         20011218                  68
# 2 2003-01-28 10:00:00         20030128                  84
# 3 2003-03-20 10:00:00         20030320                  77
# 4 2003-04-28 10:00:00         20030428                  89

# %%
location = pd.read_parquet("dim_location.parquet")

location.shape
# Out:
# (10, 8)

# %%
location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   location_id       10 non-null     int32
#  1   country           10 non-null     object
#  2   state_province    10 non-null     object
#  3   city              10 non-null     object
#  4   location_type     10 non-null     object
#  5   location_weight   10 non-null     object
#  6   foot_traffic_min  10 non-null     int32
#  7   foot_traffic_max  10 non-null     int32
# dtypes: int32(3), object(5)
# memory usage: 648.0+ bytes

# %%
location.head()
# Out:
#    location_id country    state_province         city location_type  \
# 0            1  Canada           Ontario      Toronto         Urban
# 1            2  Canada           Ontario       Ottawa         Urban
# 2            3  Canada           Ontario  Mississauga      Suburban
# 3            4  Canada            Quebec     Montreal         Urban
# 4            5  Canada  British Columbia    Vancouver         Urban
#
#   location_weight  foot_traffic_min  foot_traffic_max
# 0            0.27                75                90
# 1            0.12                75                90
# 2            0.09                50                70
# 3            0.20                75                90
# 4            0.09                75                90

# %%
inventory = pd.read_parquet("inventory.parquet")

inventory.shape
# Out:
# (846000, 10)

# %%
inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846000 entries, 0 to 845999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   inventory_id    846000 non-null  int32
#  1   product_id      846000 non-null  int32
#  2   store_id        846000 non-null  int32
#  3   snapshot_month  846000 non-null  object
#  4   starting_stock  846000 non-null  int32
#  5   received_stock  846000 non-null  int32
#  6   sold_units      846000 non-null  int32
#  7   closing_stock   846000 non-null  int32
#  8   backorder_flag  846000 non-null  bool
#  9   shrinkage_loss  846000 non-null  int32
# dtypes: bool(1), int32(8), object(1)
# memory usage: 33.1+ MB

# %%
inventory.head()
# Out:
#    inventory_id  product_id  store_id snapshot_month  starting_stock  \
# 0       1648889         361        25     2025-01-01              38
# 1       1648890         361        25     2025-02-01              38
# 2       1648891         361        25     2025-03-01              37
# 3       1648892         361        25     2025-04-01              36
# 4       1648893         361        25     2025-05-01              36
#
#    received_stock  sold_units  closing_stock  backorder_flag  shrinkage_loss
# 0               0           0             38           False               0
# 1               0           1             37           False               0
# 2               0           1             36           False               0
# 3               1           1             36           False               0
# 4               1           3             34           False               0

# %%
brand = pd.read_parquet("dim_brand.parquet")

brand.shape
# Out:
# (46, 2)

# %%
brand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Brand_ID    46 non-null     int32
#  1   Brand_Name  46 non-null     object
# dtypes: int32(1), object(1)
# memory usage: 680.0+ bytes

# %%
brand.head()
# Out:
#    Brand_ID Brand_Name
# 0         1    Philips
# 1         2    Samsung
# 2         3    Hisense
# 3         4    Toshiba
# 4         5       Sony

# %%
category = pd.read_parquet("dim_category.parquet")

category.shape
# Out:
# (10, 2)

# %%
category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category_id    10 non-null     int32
#  1   category_name  10 non-null     object
# dtypes: int32(1), object(1)
# memory usage: 248.0+ bytes

# %%
category.head()
# Out:
#    category_id  category_name
# 0            1    Televisions
# 1            2      Computing
# 2            3    Home Cinema
# 3            4        Cameras
# 4            5  Home Security

# %%
subcategory = pd.read_parquet("dim_subcategory.parquet")

subcategory.shape
# Out:
# (29, 3)

# %%
subcategory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   subcategory_id    29 non-null     int32
#  1   subcategory_name  29 non-null     object
#  2   category_id       29 non-null     int32
# dtypes: int32(2), object(1)
# memory usage: 592.0+ bytes

# %%
subcategory.head()
# Out:
#    subcategory_id subcategory_name  category_id
# 0               1              TVs            1
# 1               2   TV Accessories            1
# 2               3          Laptops            2
# 3               4         Desktops            2
# 4               5         Monitors            2

# %%
date = pd.read_parquet("dim_date.parquet")

date.shape
# Out:
# (9479, 13)

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9479 entries, 0 to 9478
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date_id         9479 non-null   int32
#  1   date            9479 non-null   object
#  2   year            9479 non-null   int32
#  3   quarter         9479 non-null   int32
#  4   month           9479 non-null   int32
#  5   month_name      9479 non-null   object
#  6   day             9479 non-null   int32
#  7   week_of_year    9479 non-null   int32
#  8   day_of_week     9479 non-null   int32
#  9   day_name        9479 non-null   object
#  10  is_weekend      9479 non-null   bool
#  11  is_month_start  9479 non-null   bool
#  12  is_month_end    9479 non-null   bool
# dtypes: bool(3), int32(7), object(3)
# memory usage: 509.3+ KB

# %%
date.head()
# Out:
#     date_id        date  year  quarter  month month_name  day  week_of_year  \
# 0  20010530  2001-05-30  2001        2      5        May   30            22
# 1  20010531  2001-05-31  2001        2      5        May   31            22
# 2  20010601  2001-06-01  2001        2      6       June    1            22
# 3  20010602  2001-06-02  2001        2      6       June    2            22
# 4  20010603  2001-06-03  2001        2      6       June    3            22
#
#    day_of_week   day_name  is_weekend  is_month_start  is_month_end
# 0            3  Wednesday       False           False         False
# 1            4   Thursday       False           False          True
# 2            5     Friday       False            True         False
# 3            6   Saturday        True           False         False
# 4            0     Sunday        True           False         False

# %%
promotion = pd.read_parquet("dim_promotion.parquet")

promotion.shape
# Out:
# (150, 13)

# %%
promotion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   promo_id             150 non-null    int32
#  1   promo_name           150 non-null    object
#  2   promo_type           150 non-null    object
#  3   discount_type        150 non-null    object
#  4   discount_value       150 non-null    object
#  5   promo_start_date     150 non-null    datetime64[us]
#  6   promo_start_date_id  150 non-null    int32
#  7   promo_end_date       150 non-null    datetime64[us]
#  8   promo_end_date_id    150 non-null    int32
#  9   promo_duration       150 non-null    int32
#  10  promo_code           150 non-null    object
#  11  is_active            150 non-null    bool
#  12  promo_description    150 non-null    object
# dtypes: bool(1), datetime64[us](2), int32(4), object(6)
# memory usage: 12.0+ KB

# %%
promotion.head()
# Out:
#    promo_id                  promo_name promo_type          discount_type  \
# 0         1          Weekend Flash Sale      Flash  Fixed_Amount_Discount
# 1         2            Mobile Life Sale      Major    Percentage_Discount
# 2         3  Customer Appreciation Sale      Major  Fixed_Amount_Discount
# 3         4         Limited Time Offers     Medium  Fixed_Amount_Discount
# 4         5          New Year Mega Sale      Major    Percentage_Discount
#
#   discount_value promo_start_date  promo_start_date_id promo_end_date  \
# 0          25.00       2023-12-10             20231210     2023-12-11
# 1           0.10       2023-07-24             20230724     2023-08-07
# 2          25.00       2023-07-15             20230715     2023-07-29
# 3          20.00       2023-12-31             20231231     2024-01-07
# 4           0.05       2023-02-21             20230221     2023-03-07
#
#    promo_end_date_id  promo_duration    promo_code  is_active  \
# ...

# %%
campaign = pd.read_parquet("dim_campaign.parquet")

campaign.shape
# Out:
# (120, 8)

# %%
campaign.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   campaign_id             120 non-null    int32
#  1   campaign_name           120 non-null    object
#  2   campaign_channel        120 non-null    object
#  3   promo_id                80 non-null     float64
#  4   campaign_start_date     120 non-null    datetime64[us]
#  5   campaign_start_date_id  120 non-null    int32
#  6   campaign_end_date       120 non-null    datetime64[us]
#  7   campaign_end_date_id    120 non-null    int32
# dtypes: datetime64[us](2), float64(1), int32(3), object(2)
# memory usage: 6.2+ KB

# %%
campaign.head()
# Out:
#    campaign_id campaign_name campaign_channel  promo_id campaign_start_date  \
# 0            1   Campaign #1            Email      16.0          2023-09-26
# 1            2   Campaign #2            Email       NaN          2023-01-12
# 2            3   Campaign #3              SMS       NaN          2023-09-11
# 3            4   Campaign #4            Email      19.0          2023-02-09
# 4            5   Campaign #5              SMS       NaN          2023-12-15
#
#    campaign_start_date_id   campaign_end_date  campaign_end_date_id
# 0                20230926 2023-09-26 03:00:00              20230926
# 1                20230112 2023-01-13 00:00:00              20230113
# 2                20230911 2023-09-11 12:00:00              20230911
# 3                20230209 2023-02-09 12:00:00              20230209
# 4                20231215 2023-12-16 00:00:00              20231216

# %% [markdown]
# ## Data Cleaning

# %%
sales.isnull().sum()
# Out:
# sale_id                       0
# transaction_id                0
# session_id               679257
# transaction_timestamp         0
# transaction_date_id           0
# product_id                    0
# quantity                      0
# unit_cost                     0
# unit_price                    0
# line_cost                     0
# line_total                    0
# aov_category                  0
# dtype: int64

# %%
inventory.isnull().sum()
# Out:
# inventory_id      0
# product_id        0
# store_id          0
# snapshot_month    0
# starting_stock    0
# received_stock    0
# sold_units        0
# closing_stock     0
# backorder_flag    0
# shrinkage_loss    0
# dtype: int64

# %%
customer.isnull().sum()
# Out:
# customer_id                0
# email_address              0
# first_name                 0
# last_name                  0
# gender                     0
# customer_persona           0
# birth_date                 0
# birth_year                 0
# location_id                0
# signup_date                0
# signup_date_id             0
# signup_channel             0
# loyalty_status             0
# estimated_annual_income    0
# email_opt_in               0
# sms_opt_in                 0
# dtype: int64

# %%
product.isnull().sum()
# Out:
# product_id         0
# product_name       0
# category_id        0
# subcategory_id     0
# brand_id           0
# unit_cost          0
# unit_price         0
# warranty_years     0
# product_segment    0
# dtype: int64

# %%
store.isnull().sum()
# Out:
# store_id              0
# store_name            0
# location_id           0
# store_type            0
# store_size            0
# opening_date          0
# opening_date_id       0
# foot_traffic_index    0
# dtype: int64

# %%
location.isnull().sum()
# Out:
# location_id         0
# country             0
# state_province      0
# city                0
# location_type       0
# location_weight     0
# foot_traffic_min    0
# foot_traffic_max    0
# dtype: int64

# %%
brand.isnull().sum()
# Out:
# Brand_ID      0
# Brand_Name    0
# dtype: int64

# %%
category.isnull().sum()
# Out:
# category_id      0
# category_name    0
# dtype: int64

# %%
subcategory.isnull().sum()
# Out:
# subcategory_id      0
# subcategory_name    0
# category_id         0
# dtype: int64

# %%
date.isnull().sum()
# Out:
# date_id           0
# date              0
# year              0
# quarter           0
# month             0
# month_name        0
# day               0
# week_of_year      0
# day_of_week       0
# day_name          0
# is_weekend        0
# is_month_start    0
# is_month_end      0
# dtype: int64

# %%
promotion.isnull().sum()
# Out:
# promo_id               0
# promo_name             0
# promo_type             0
# discount_type          0
# discount_value         0
# promo_start_date       0
# promo_start_date_id    0
# promo_end_date         0
# promo_end_date_id      0
# promo_duration         0
# promo_code             0
# is_active              0
# promo_description      0
# dtype: int64

# %%
campaign.isnull().sum()
# Out:
# campaign_id                0
# campaign_name              0
# campaign_channel           0
# promo_id                  40
# campaign_start_date        0
# campaign_start_date_id     0
# campaign_end_date          0
# campaign_end_date_id       0
# dtype: int64

# %%
sales.duplicated().sum()
inventory.duplicated().sum()
customer.duplicated().sum()
product.duplicated().sum()
store.duplicated().sum()
location.duplicated().sum()
brand.duplicated().sum()
category.duplicated().sum()
subcategory.duplicated().sum()
date.duplicated().sum()
promotion.duplicated().sum()
campaign.duplicated().sum()
# Out:
# np.int64(0)

# %%
sales["unit_cost"] = pd.to_numeric(sales["unit_cost"])
sales["unit_price"] = pd.to_numeric(sales["unit_price"])
sales["line_cost"] = pd.to_numeric(sales["line_cost"])
sales["line_total"] = pd.to_numeric(sales["line_total"])

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1799836 entries, 0 to 1799835
# Data columns (total 12 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   sale_id                int32
#  1   transaction_id         int32
#  2   session_id             float64
#  3   transaction_timestamp  datetime64[us]
#  4   transaction_date_id    int32
#  5   product_id             int32
#  6   quantity               int32
#  7   unit_cost              float64
#  8   unit_price             float64
#  9   line_cost              float64
#  10  line_total             float64
#  11  aov_category           object
# dtypes: datetime64[us](1), float64(5), int32(5), object(1)
# memory usage: 130.5+ MB

# %% [markdown]
# ## Saving Cleaned Dataset

# %%
sales.to_parquet("cleaned_fact_sale.parquet", index=False)
customer.to_parquet("cleaned_dim_customer.parquet", index=False)
product.to_parquet("cleaned_dim_product.parquet", index=False)
store.to_parquet("cleaned_dim_store.parquet", index=False)
inventory.to_parquet("cleaned_inventory.parquet", index=False)

# %% [markdown]
# ### Tasks Completed
#
# - Downloaded and organized the Omnichannel Retail Analytics dataset.
# - Set up the project structure and Jupyter Notebook environment.
# - Loaded all fact and dimension tables into Python.
# - Explored dataset structure using shape, info(), columns, and head().
# - Performed initial data quality assessment by checking missing values and duplicate records.
# - Corrected incorrect data types in the sales dataset.
# - Saved cleaned datasets for further analysis.
#
# ### Outcome
#
# The dataset has been successfully explored, validated, and prepared for SQL database implementation in Week 2.
